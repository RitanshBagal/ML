# %%
import numpy as np
import pandas as pd

# %%
dict1 = {
    "name" : ['hehe', 'Sus','Drake','Smoke'],
    "marks" : [99, 98,100,97],
    "city" : ['Jammu', 'Chandigarh','delhi','chennai']
}

# %%
df = pd.DataFrame(dict1)
df
# Out:
#     name  marks        city
# 0   hehe     99       Jammu
# 1    Sus     98  Chandigarh
# 2  Drake    100       delhi
# 3  Smoke     97     chennai

# %%
df.to_csv('friendss.csv', index=False)

# %%
df.head(2)
# Out:
#    name  marks        city
# 0  hehe     99       Jammu
# 1   Sus     98  Chandigarh

# %%
df.tail(1)
# Out:
#     name  marks     city
# 3  Smoke     97  chennai

# %%
df.describe()
# Out:
#             marks
# count    4.000000
# mean    98.500000
# std      1.290994
# min     97.000000
# 25%     97.750000
# 50%     98.500000
# 75%     99.250000
# max    100.000000

# %%
fetchTrain = pd.read_csv('friends.csv')
fetchTrain
# Out:
#    Train No  Speed        City
# 0      1234     99       Jammu
# 1      5678     98  Chandigarh
# 2      4567    100       delhi
# 3      1253     97     chennai

# %%
fetchTrain['Speed'][0] = 1000
# Out:
# C:\Users\Ritansh\AppData\Local\Temp\ipykernel_34600\1346230853.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fetchTrain['Speed'][0] = 1000

# %%
fetchTrain
# Out:
#    Train No  Speed        City
# 0      1234   1000       Jammu
# 1      5678     98  Chandigarh
# 2      4567    100       delhi
# 3      1253     97     chennai

# %%
fetchTrain.to_csv('trains.csv')

# %%
fetchTrain.index = ['first', 'second', 'third', 'fourth']

# %%
fetchTrain
# Out:
#         Train No  Speed        City
# first       1234   1000       Jammu
# second      5678     98  Chandigarh
# third       4567    100       delhi
# fourth      1253     97     chennai

# %%
ser = pd.Series(np.random.rand(34))
ser
# Out:
# 0     0.469608
# 1     0.991811
# 2     0.887288
# 3     0.810097
# 4     0.033855
# 5     0.144999
# 6     0.623664
# 7     0.911554
# 8     0.319625
# 9     0.363881
# 10    0.913514
# 11    0.375631
# 12    0.810325
# 13    0.820491
# 14    0.565354
# 15    0.134094
# 16    0.972701
# 17    0.035427
# 18    0.921682
# 19    0.248975
# 20    0.023724
# 21    0.963725
# 22    0.501969
# 23    0.810890
# 24    0.544338
# 25    0.993268
# 26    0.565346
# 27    0.471010
# 28    0.385740
# 29    0.712544
# 30    0.607562
# 31    0.327664
# 32    0.066613
# 33    0.537755
# dtype: float64

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
newdf = pd.DataFrame(np.random.rand(334,5), index = np.arange(334))
newdf
# Out:
#             0         1         2         3         4
# 0    0.940870  0.171491  0.343396  0.920080  0.408009
# 1    0.396008  0.212970  0.663081  0.710746  0.240191
# 2    0.734141  0.590925  0.062301  0.315324  0.637952
# 3    0.647791  0.766065  0.570197  0.836061  0.656975
# 4    0.521769  0.521324  0.040614  0.531556  0.093112
# ..        ...       ...       ...       ...       ...
# 329  0.322779  0.508133  0.622143  0.769672  0.188600
# 330  0.015169  0.677167  0.535355  0.799241  0.881877
# 331  0.395742  0.542926  0.980640  0.420882  0.198102
# 332  0.385662  0.368135  0.957903  0.637010  0.695030
# 333  0.267806  0.065057  0.162899  0.891796  0.422088
#
# [334 rows x 5 columns]

# %%
newdf.head()
# Out:
#           0         1         2         3         4
# 0  0.940870  0.171491  0.343396  0.920080  0.408009
# 1  0.396008  0.212970  0.663081  0.710746  0.240191
# 2  0.734141  0.590925  0.062301  0.315324  0.637952
# 3  0.647791  0.766065  0.570197  0.836061  0.656975
# 4  0.521769  0.521324  0.040614  0.531556  0.093112

# %%
type(newdf)
# Out:
# pandas.core.frame.DataFrame

# %%
newdf.describe()
# Out:
#                 0           1           2           3           4
# count  334.000000  334.000000  334.000000  334.000000  334.000000
# mean     0
# %%
type(newdf[0])
# Out:
# pandas.core.series.Series

# %%
newdf2 = newdf

# %%
newdf2.loc[0,0] = 26

# %%
newdf2.head(2)
# Out:
#           0         1         2         3         4
# 0        26  0.171491  0.343396  0.920080  0.408009
# 1  0.396008  0.212970  0.663081  0.710746  0.240191

# %%
newdf.head(2)
# Out:
#           0         1         2         3         4
# 0        26  0.171491  0.343396  0.920080  0.408009
# 1  0.396008  0.212970  0.663081  0.710746  0.240191

# %%
newdf.columns = list("ABCDE")

# %%
newdf.head()
# Out:
#           A         B         C         D         E
# 0        26  0.171491  0.343396  0.920080  0.408009
# 1  0.396008  0.212970  0.663081  0.710746  0.240191
# 2  0.734141  0.590925  0.062301  0.315324  0.637952
# 3  0.647791  0.766065  0.570197  0.836061  0.656975
# 4  0.521769  0.521324  0.040614  0.531556  0.093112

# %%
newdf.loc[0, 'A'] = 47

# %%
newdf.head(2)
# Out:
#           A         B         C         D         E
# 0        47  0.171491  0.343396  0.920080  0.408009
# 1  0.396008  0.212970  0.663081  0.710746  0.240191

# %%
newdf = newdf.drop('E',axis = 1)

# %%
newdf.head(2)
# Out:
#           A         B         C         D
# 0        47  0.171491  0.343396  0.920080
# 1  0.396008  0.212970  0.663081  0.710746

# %%
newdf.loc[[1,2],['C','D']]
# Out:
#           C         D
# 1  0.663081  0.710746
# 2  0.062301  0.315324

# %%
newdf.loc[ : ,['C','D']]
# Out:
#             C         D
# 0    0.343396  0.920080
# 1    0.663081  0.710746
# 2    0.062301  0.315324
# 3    0.570197  0.836061
# 4    0.040614  0.531556
# ..        ...       ...
# 329  0.622143  0.769672
# 330  0.535355  0.799241
# 331  0.980640  0.420882
# 332  0.957903  0.637010
# 333  0.162899  0.891796
#
# [334 rows x 2 columns]

# %%
newdf.loc[[1,2], : ]
# Out:
#           A         B         C         D
# 1  0.396008  0.212970  0.663081  0.710746
# 2  0.734141  0.590925  0.062301  0.315324

# %%
newdf.loc[(newdf['A']<0.3) & (newdf['C']>0.1)]
# Out:
#             A         B         C         D
# 7    0.243423  0.467190  0.648700  0.202114
# 8    0.243369  0.767702  0.918142  0.478842
# 14   0.283987  0.710549  0.972320  0.484604
# 21    0.01373  0.740392  0.177112  0.021098
# 23   0.228276  0.776905  0.432866  0.668849
# ..        ...       ...       ...       ...
# 317  0.208185  0.545514  0.138841  0.759265
# 321  0.070538  0.226787  0.512064  0.600949
# 322  0.244657  0.744383  0.603940  0.022248
# 330  0.015169  0.677167  0.535355  0.799241
# 333  0.267806  0.065057  0.162899  0.891796
#
# [83 rows x 4 columns]

# %%
newdf.drop([1,5], axis = 0, inplace = True)

# %%
newdf
# Out:
#             A         B         C         D
# 0          47  0.171491  0.343396  0.920080
# 2    0.734141  0.590925  0.062301  0.315324
# 3    0.647791  0.766065  0.570197  0.836061
# 4    0.521769  0.521324  0.040614  0.531556
# 6    0.889265  0.104865  0.033020  0.222268
# ..        ...       ...       ...       ...
# 329  0.322779  0.508133  0.622143  0.769672
# 330  0.015169  0.677167  0.535355  0.799241
# 331  0.395742  0.542926  0.980640  0.420882
# 332  0.385662  0.368135  0.957903  0.637010
# 333  0.267806  0.065057  0.162899  0.891796
#
# [332 rows x 4 columns]

# %%
newdf.head()
# Out:
#           A         B         C         D
# 0        47  0.171491  0.343396  0.920080
# 2  0.734141  0.590925  0.062301  0.315324
# 3  0.647791  0.766065  0.570197  0.836061
# 4  0.521769  0.521324  0.040614  0.531556
# 6  0.889265  0.104865  0.033020  0.222268

# %%
newdf.reset_index()
# Out:
#      index         A         B         C         D
# 0        0        47  0.171491  0.343396  0.920080
# 1        2  0.734141  0.590925  0.062301  0.315324
# 2        3  0.647791  0.766065  0.570197  0.836061
# 3        4  0.521769  0.521324  0.040614  0.531556
# 4        6  0.889265  0.104865  0.033020  0.222268
# ..     ...       ...       ...       ...       ...
# 327    329  0.322779  0.508133  0.622143  0.769672
# 328    330  0.015169  0.677167  0.535355  0.799241
# 329    331  0.395742  0.542926  0.980640  0.420882
# 330    332  0.385662  0.368135  0.957903  0.637010
# 331    333  0.267806  0.065057  0.162899  0.891796
#
# [332 rows x 5 columns]

# %%
# as you can see reset_index... makes an index named column as well but we don't want it. So we use reset_index(drop = True)

# %%
newdf.reset_index(drop = True, inplace = True)

# %%
newdf
# Out:
#             A         B         C         D
# 0          47  0.171491  0.343396  0.920080
# 1    0.734141  0.590925  0.062301  0.315324
# 2    0.647791  0.766065  0.570197  0.836061
# 3    0.521769  0.521324  0.040614  0.531556
# 4    0.889265  0.104865  0.033020  0.222268
# ..        ...       ...       ...       ...
# 327  0.322779  0.508133  0.622143  0.769672
# 328  0.015169  0.677167  0.535355  0.799241
# 329  0.395742  0.542926  0.980640  0.420882
# 330  0.385662  0.368135  0.957903  0.637010
# 331  0.267806  0.065057  0.162899  0.891796
#
# [332 rows x 4 columns]

# %%
newdf.loc[:, ['B']] = None

# %%
newdf.isnull() # boolean.... if null -> returns true else -> false
# Out:
#          A     B      C      D
# 0    False  True  False  False
# 1    False  True  False  False
# 2    False  True  False  False
# 3    False  True  False  False
# 4    False  True  False  False
# ..     ...   ...    ...    ...
# 327  False  True  False  False
# 328  False  True  False  False
# 329  False  True  False  False
# 330  False  True  False  False
# 331  False  True  False  False
#
# [332 rows x 4 columns]

# %%
newdf.loc[:, ['B']]= 26
newdf
# Out:
#             A   B         C         D
# 0          47  26  0.343396  0.920080
# 1    0.734141  26  0.062301  0.315324
# 2    0.647791  26  0.570197  0.836061
# 3    0.521769  26  0.040614  0.531556
# 4    0.889265  26  0.033020  0.222268
# ..        ...  ..       ...       ...
# 327  0.322779  26  0.622143  0.769672
# 328  0.015169  26  0.535355  0.799241
# 329  0.395742  26  0.980640  0.420882
# 330  0.385662  26  0.957903  0.637010
# 331  0.267806  26  0.162899  0.891796
#
# [332 rows x 4 columns]

# %%
newdf.isnull()
# Out:
#          A      B      C      D
# 0    False  False  False  False
# 1    False  False  False  False
# 2    False  False  False  False
# 3    False  False  False  False
# 4    False  False  False  False
# ..     ...    ...    ...    ...
# 327  False  False  False  False
# 328  False  False  False  False
# 329  False  False  False  False
# 330  False  False  False  False
# 331  False  False  False  False
#
# [332 rows x 4 columns]

# %%
newdf.head()
# Out:
#           A   B         C         D
# 0        47  26  0.343396  0.920080
# 1  0.734141  26  0.062301  0.315324
# 2  0.647791  26  0.570197  0.836061
# 3  0.521769  26  0.040614  0.531556
# 4  0.889265  26  0.033020  0.222268

# %%
df = pd.DataFrame({
    "name": ['AB', 'BC', 'CD'],
    "toy" : [np.nan, 'Batty', np.nan],
    "born" : [pd.NaT, pd.Timestamp("1940-04-25"),pd.NaT]
})

# %%
df.head()
# Out:
#   name    toy       born
# 0   AB    NaN        NaT
# 1   BC  Batty 1940-04-25
# 2   CD    NaN        NaT

# %%
df.dropna()
# Out:
#   name    toy       born
# 1   BC  Batty 1940-04-25

# %%
df.head()
# Out:
#   name    toy       born
# 0   AB    NaN        NaT
# 1   BC  Batty 1940-04-25
# 2   CD    NaN        NaT

# %%
df.dropna(how = 'all', axis = 1)
# Out:
#   name    toy       born
# 0   AB    NaN        NaT
# 1   BC  Batty 1940-04-25
# 2   CD    NaN        NaT
